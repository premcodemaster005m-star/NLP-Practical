# %% [markdown]
# <a href="https://colab.research.google.com/github/premcodemaster005m-star/NLP-Practical/blob/main/1_Python_Basics_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data types
name = "NLP Lab"
hours = 30
pi = 3.14
topics = ["Tokenization", "POS tagging", "NER"]

# %%
# Control structures
if hours > 25:
    print("Sufficient hours for learning Python.")
else:
    print("Add more practice hours.")
# Out:
# Sufficient hours for learning Python.

# %%
# Loop
for topic in topics:
    print(f"Learning topic: {topic}")
# Out:
# Learning topic: Tokenization
# Learning topic: POS tagging
# Learning topic: NER

# %%
# Function
def greet(student_name):
    return "Welcome to " + student_name

print(greet("NLP & AI"))
# Out:
# Welcome to NLP & AI

# %%
# Define a dictionary
student = {
    "name": "Prem",
    "course": "NLP",
    "hours": 30
}

# Print dictionary elements using a loop
for key, value in student.items():
    print(key, ":", value)
# Out:
# name : Prem
# course : NLP
# hours : 30
