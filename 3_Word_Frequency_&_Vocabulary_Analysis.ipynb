# %% [markdown]
# <a href="https://colab.research.google.com/github/premcodemaster005m-star/NLP-Practical/blob/main/3_Word_Frequency_%26_Vocabulary_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# download required dataset
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# sample text
text = " natrual language processing enables machines to understand human languages undeestanding "

# %%
# tokenization
tokens = word_tokenize(text)

# %%
# frequency Distribution
freq_dist = FreqDist(tokens)

# %%
# display word frequencies
print("Word Frequencies:", freq_dist)
print("Most common Word:", freq_dist.most_common(5))
print("Vocabulary Size:", len(freq_dist))
# Out:
# Word Frequencies: <FreqDist with 10 samples and 10 outcomes>
# Most common Word: [('natrual', 1), ('language', 1), ('processing', 1), ('enables', 1), ('machines', 1)]
# Vocabulary Size: 10
